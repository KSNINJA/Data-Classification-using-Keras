# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
import keras 
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

n_pts = 500
X, y = datasets.make_circles(n_samples=n_pts, random_state=123, noise=0.1, factor=0.2)

plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])

# %%
model = Sequential()
model.add(Dense(4, input_shape = (2,), activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))
model.compile(Adam(lr=0.01), 'binary_crossentropy', metrics=['accuracy'])
h = model.fit(x=X, y=y, verbose=2, batch_size=100, epochs=100, shuffle='true')
# Out:
# Epoch 1/100
# 5/5 - 0s - loss: 0.7115 - accuracy: 0.5000
# Epoch 2/100
# 5/5 - 0s - loss: 0.6996 - accuracy: 0.5000
# Epoch 3/100
# 5/5 - 0s - loss: 0.6935 - accuracy: 0.4880
# Epoch 4/100
# 5/5 - 0s - loss: 0.6922 - accuracy: 0.5380
# Epoch 5/100
# 5/5 - 0s - loss: 0.6924 - accuracy: 0.5420
# Epoch 6/100
# 5/5 - 0s - loss: 0.6929 - accuracy: 0.5000
# Epoch 7/100
# 5/5 - 0s - loss: 0.6925 - accuracy: 0.5000
# Epoch 8/100
# 5/5 - 0s - loss: 0.6918 - accuracy: 0.5620
# Epoch 9/100
# 5/5 - 0s - loss: 0.6914 - accuracy: 0.6900
# Epoch 10/100
# 5/5 - 0s - loss: 0.6910 - accuracy: 0.6620
# Epoch 11/100
# 5/5 - 0s - loss: 0.6908 - accuracy: 0.5100
# Epoch 12/100
# 5/5 - 0s - loss: 0.6905 - accuracy: 0.5700
# Epoch 13/100
# 5/5 - 0s - loss: 0.6904 - accuracy: 0.7000
# Epoch 14/100
# 5/5 - 0s - loss: 0.6900 - accuracy: 0.7020
# Epoch 15/100
# 5/5 - 0s - loss: 0.6893 - accuracy: 0.7040
# Epoch 16/100
# 5/5 - 0s - loss: 0.6888 - accuracy: 0.7220
# Epoch 17/100
# 5/5 - 0s - loss: 0.6883 - accuracy: 0.7280
# Epoch 18/100
# 5/5 - 0s - loss: 0.6877 - accuracy: 0.7220
# Epoch 19/100
# 5/5 - 0s - loss: 0.6869 - accuracy: 0.7180
# Epoch 20/100
# 5/5 - 0s - loss: 0.6862 - accuracy: 0.7140
# Epoch 21/100
# 5/5 - 0s - loss: 0.6853 - accuracy: 0.7180
# Epoch 22/100
# 5/5 - 0s - loss: 0.6842 - accuracy: 0.7240
# Epoch 23/100
# 5/5 - 0s - loss: 0.6832 - accuracy: 0.7140
# Epoch 24/100
# 5/5 - 0s - loss: 0.6819 - accuracy: 0.7080
# Epoch 25/100
# 5/5 - 0s - loss: 0.6804 - accuracy: 0.7200
# Epoch 26/100
# 5/5 - 0s - loss: 0.6784 - accuracy: 0.7300
# Epoch 27/100
# 5/5 - 0s - loss: 0.6767 - accuracy: 0.7340
# Epoch 28/100
# 5/5 - 0s - loss: 0.6745 - accuracy: 0.7300
# Epoch 29/100
# 5/5 - 0s - loss: 0.6724 - accuracy: 0.7320
# Epoch 30/100
# 5/5 - 0s - loss: 0.6694 - accuracy: 0.7280
# Epoch 31/100
# 5/5 - 0s - loss: 0.6664 - accuracy: 0.7280
# Epoch 32/100
# 5/5 - 0s - loss: 0.6632 - accuracy: 0.7300
# Epoch 33/100
# 5/5 - 0s - loss: 0.6596 - accuracy: 0.7300
# Epoch 34/100
# 5/5 - 0s - loss: 0.6558 - accuracy: 0.7280
# Epoch 35/100
# 5/5 - 0s - loss: 0.6515 - accuracy: 0.7240
# Epoch 36/100
# 5/5 - 0s - loss: 0.6469 - accuracy: 0.7240
# Epoch 37/100
# 5/5 - 0s - loss: 0.6417 - accuracy: 0.7300
# Epoch 38/100
# 5/5 - 0s - loss: 0.6362 - accuracy: 0.7420
# Epoch 39/100
# 5/5 - 0s - loss: 0.6303 - accuracy: 0.7580
# Epoch 40/100
# 5/5 - 0s - loss: 0.6240 - accuracy: 0.7720
# Epoch 41/100
# 5/5 - 0s - loss: 0.6171 - accuracy: 0.7880
# Epoch 42/100
# 5/5 - 0s - loss: 0.6099 - accuracy: 0.8120
# Epoch 43/100
# 5/5 - 0s - loss: 0.6024 - accuracy: 0.8440
# Epoch 44/100
# 5/5 - 0s - loss: 0.5944 - accuracy: 0.8540
# Epoch 45/100
# 5/5 - 0s - loss: 0.5860 - accuracy: 0.8580
# Epoch 46/100
# 5/5 - 0s - loss: 0.5772 - accuracy: 0.8800
# Epoch 47/100
# 5/5 - 0s - loss: 0.5685 - accuracy: 0.8800
# Epoch 48/100
# 5/5 - 0s - loss: 0.5593 - accuracy: 0.8860
# Epoch 49/100
# 5/5 - 0s - loss: 0.5498 - accuracy: 0.8880
# Epoch 50/100
# 5/5 - 0s - loss: 0.5402 - accuracy: 0.8900
# Epoch 51/100
# 5/5 - 0s - loss: 0.5303 - accuracy: 0.8940
# Epoch 52/100
# 5/5 - 0s - loss: 0.5206 - accuracy: 0.9020
# Epoch 53/100
# 5/5 - 0s - loss: 0.5107 - accuracy: 0.9040
# Epoch 54/100
# 5/5 - 0s - loss: 0.5007 - accuracy: 0.9060
# Epoch 55/100
# 5/5 - 0s - loss: 0.4907 - accuracy: 0.9080
# Epoch 56/100
# 5/5 - 0s - loss: 0.4808 - accuracy: 0.9140
# Epoch 57/100
# 5/5 - 0s - loss: 0.4709 - accuracy: 0.9160
# Epoch 58/100
# 5/5 - 0s - loss: 0.4612 - accuracy: 0.9200
# Epoch 59/100
# 5/5 - 0s - loss: 0.4514 - accuracy: 0.9220
# Epoch 60/100
# 5/5 - 0s - loss: 0.4417 - accuracy: 0.9220
# Epoch 61/100
# 5/5 - 0s - loss: 0.4325 - accuracy: 0.9220
# Epoch 62/100
# 5/5 - 0s - loss: 0.4231 - accuracy: 0.9220
# Epoch 63/100
# 5/5 - 0s - loss: 0.4139 - accuracy: 0.9280
# Epoch 64/100
# 5/5 - 0s - loss: 0.4049 - accuracy: 0.9320
# Epoch 65/100
# 5/5 - 0s - loss: 0.3961 - accuracy: 0.9340
# Epoch 66/100
# 5/5 - 0s - loss: 0.3876 - accuracy: 0.9380
# Epoch 67/100
# 5/5 - 0s - loss: 0.3791 - accuracy: 0.9400
# Epoch 68/100
# 5/5 - 0s - loss: 0.3710 - accuracy: 0.9420
# Epoch 69/100
# 5/5 - 0s - loss: 0.3630 - accuracy: 0.9420
# Epoch 70/100
# 5/5 - 0s - loss: 0.3555 - accuracy: 0.9460
# Epoch 71/100
# 5/5 - 0s - loss: 0.3478 - accuracy: 0.9480
# Epoch 72/100
# 5/5 - 0s - loss: 0.3404 - accuracy: 0.9480
# Epoch 73/100
# 5/5 - 0s - loss: 0.3333 - accuracy: 0.9480
# Epoch 74/100
# 5/5 - 0s - loss: 0.3265 - accuracy: 0.9480
# Epoch 75/100
# 5/5 - 0s - loss: 0.3197 - accuracy: 0.9520
# Epoch 76/100
# 5/5 - 0s - loss: 0.3133 - accuracy: 0.9540
# Epoch 77/100
# 5/5 - 0s - loss: 0.3071 - accuracy: 0.9560
# Epoch 78/100
# 5/5 - 0s - loss: 0.3009 - accuracy: 0.9640
# Epoch 79/100
# 5/5 - 0s - loss: 0.2950 - accuracy: 0.9640
# Epoch 80/100
# 5/5 - 0s - loss: 0.2893 - accuracy: 0.9680
# Epoch 81/100
# 5/5 - 0s - loss: 0.2837 - accuracy: 0.9700
# Epoch 82/100
# 5/5 - 0s - loss: 0.2783 - accuracy: 0.9740
# Epoch 83/100
# 5/5 - 0s - loss: 0.2731 - accuracy: 0.9780
# Epoch 84/100
# 5/5 - 0s - loss: 0.2681 - accuracy: 0.9800
# Epoch 85/100
# 5/5 - 0s - loss: 0.2632 - accuracy: 0.9820
# Epoch 86/100
# 5/5 - 0s - loss: 0.2584 - accuracy: 0.9880
# Epoch 87/100
# 5/5 - 0s - loss: 0.2537 - accuracy: 0.9900
# Epoch 88/100
# 5/5 - 0s - loss: 0.2493 - accuracy: 0.9900
# Epoch 89/100
# 5/5 - 0s - loss: 0.2449 - accuracy: 0.9900
# Epoch 90/100
# 5/5 - 0s - loss: 0.2407 - accuracy: 0.9900
# Epoch 91/100
# 5/5 - 0s - loss: 0.2366 - accuracy: 0.9920
# Epoch 92/100
# 5/5 - 0s - loss: 0.2326 - accuracy: 0.9940
# Epoch 93/100
# 5/5 - 0s - loss: 0.2287 - accuracy: 0.9980
# Epoch 94/100
# 5/5 - 0s - loss: 0.2250 - accuracy: 0.9980
# Epoch 95/100
# 5/5 - 0s - loss: 0.2213 - accuracy: 0.9980
# Epoch 96/100
# 5/5 - 0s - loss: 0.2177 - accuracy: 0.9980
# Epoch 97/100
# 5/5 - 0s - loss: 0.2142 - accuracy: 0.9980
# Epoch 98/100
# 5/5 - 0s - loss: 0.2108 - accuracy: 0.9980
# Epoch 99/100
# 5/5 - 0s - loss: 0.2075 - accuracy: 1.0000
# Epoch 100/100
# 5/5 - 0s - loss: 0.2043 - accuracy: 1.0000

# %%
def plot_decision_boundary(X, y, model):
    x_span = np.linspace(min(X[:,0]) - 0.25, max(X[:,0]) + 0.25)
    y_span = np.linspace(min(X[:,1]) - 0.25, max(X[:,1]) + 0.25)
    xx, yy = np.meshgrid(x_span, y_span)
    grid = np.c_[xx.ravel(), yy.ravel()]
    pred_func = model.predict(grid)
    z = pred_func.reshape(xx.shape)
    plt.contourf(xx, yy, z)

plot_decision_boundary(X, y, model)
